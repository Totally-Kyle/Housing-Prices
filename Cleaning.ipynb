# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
raw_df = pd.read_csv("/Users/sa24/Desktop/Housing-Prices/house-prices-advanced-regression-techniques/train.csv")

# %%
drop_columns = ["Id", "Alley", "Street", "SaleType", "PoolQC", "MiscFeature", "Fence", "MasVnrType", "GarageCars", "TotRmsAbvGrd", "ExterQual", "MSZoning", "Condition2", "Utilities"] 
cleaned_data = raw_df.drop(drop_columns, axis= 1)
cleaned_data.head()
# Out:
#    MSSubClass  LotFrontage  LotArea LotShape LandContour LotConfig LandSlope  \
# 0          60         65.0     8450      Reg         Lvl    Inside       Gtl
# 1          20         80.0     9600      Reg         Lvl       FR2       Gtl
# 2          60         68.0    11250      IR1         Lvl    Inside       Gtl
# 3          70         60.0     9550      IR1         Lvl    Corner       Gtl
# 4          60         84.0    14260      IR1         Lvl       FR2       Gtl
#
#   Neighborhood Condition1 BldgType  ... OpenPorchSF  EnclosedPorch  3SsnPorch  \
# 0      CollgCr       Norm     1Fam  ...          61              0          0
# 1      Veenker      Feedr     1Fam  ...           0              0          0
# 2      CollgCr       Norm     1Fam  ...          42              0          0
# 3      Crawfor       Norm     1Fam  ...          35            272          0
# 4      NoRidge       Norm     1Fam  ...          84              0          0
#
# ...

# %%
cleaned_data.to_csv("Cleaned_df.csv")
